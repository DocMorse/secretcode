# %% [markdown]
# <h1>Relational Operators</h1>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#6.2 Practical Activity 1

"""
LONG COMMENT- Relational Operators
-----------------------
So far all of your conditional statements have used the
== operator to test if the value on the left is equal to the
value on the right. This testing for equality is known as a
relational operator.

There are others and you can see them
in the image at the top of this set of activities.
-------------------------------------
"""

#-------------Global Variables------------------

#====> Initialise a variable called numOne
#====> Assign the integer 0 to it


#====> Initialise a variable called numTwo
#====> Assign the integer 0 to it


#--------------------Subprograms-----------------------

# Creating a subprogram called equalOrNot
# It has two parameters called n1 and n2
def equalOrNot(n1, n2):

  #====> The subprogram will use a conditional statement
  #====> to test it n1 and n2 are equal.
  #====> If they are equal it will output "equal", otherwise
  #====> it will output "not equal".




#--------------------Main Program----------------------

#====> Ask the user to input number 1
#====> Cast the input to integer as it is
#====> Assigned to numOne


#====> Ask the user to input number 1
#====> Cast the input to integer as it is
#====> Assigned to numTwo


#====> Call the equalOrNot subprogram
#====> Use numOne and numTwo as arguments

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
#6.2 Practical Activity 2

#-------------Global Variables------------------

#====> Initialise a variable called numOne
#====> Assign the integer 0 to it


#====> Initialise a variable called numTwo
#====> Assign the integer 0 to it


#--------------------Subprograms-----------------------

#====> Create a subprogram called greatestNumber
#====> It must have two parameters called num1 and num2

  #====> The subprogram will use a branched conditional statement
  #====> If num1 is greater than num2 then output "number 1 is greater".
  #====> If num2 is greater than num1 then output "number 2 is greater".
  #====> Otherwise output "Both numbers are equal".






#--------------------Main Program----------------------

#====> Ask the user to input number 1
#====> Cast the input to integer as it is
#====> Assigned to numOne


#====> Ask the user to input number 1
#====> Cast the input to integer as it is
#====> Assigned to numTwo


#====> Call the greatestNumber subprogram
#====> Use numOne and numTwo as arguments

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
#6.2 Practical Activity 3

#-------------Global Variables------------------

#====> Initialise a variable called userNumber
#====> Assign the integer 0 to it


#--------------------Main Program----------------------

#====> Ask the user to input a number greater than or equal to 50
#====> Cast the input to integer as it is assigned to userNumber


#====> Use a conditional statement to test if userNumber is
#====> greater than or equal to 50. If it is, then the program
#====> outputs "Your number is valid". Otherwise output
#====> "Your number is invalid".

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
#6.2 Practical Activity 4

#-------------Global Variables------------------

# Initialising a variable called userHome
# Assigning an empty string to it
userHome = ""

#====> Initialise a variable called resultString
#====> Assign an empty string to it


#--------------------Subprograms-----------------------

#====> Create a subprogram called notExeter
#====> It must have one parameter called dataIn

  #====> The subprogram will use a conditional statement
  #====> to test it dataIn is NOT EQUAL to "Exeter".
  #====> If they are not equal it will return "notExe", otherwise
  #====> it will return "isExe".





#--------------------Main Program----------------------
#====> Ask the user to input where they live
#====> Assign their input to userHome


#====> Call the notExeter subprogram
#====> Use userHome as the argument
#====> Assign the returned value to resultString


#====> Use a conditional statement to test resultString
#====> If the value is notExe the program will output the string
#====> "You don't live in Exeter".
#====> Otherwise it will output "You do live in Exeter".

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
#6.2 Practical Activity 5

#-------------Global Variables------------------

#====> Initialise a variable called userNumber
#====> Assign the integer 0 to it


#====> Initialise a variable called result
#====> Assign the integer 0 to it


#--------------------Subprograms-----------------------

#====> Create a subprogram called moduloByTwo
#====> It must have one parameter called numberIn

  # Calculating the modulo of numberIn when divided by 2
  # Re-assigning the result to numberIn (overwriting it)
  numberIn = numberIn % 2
  #====> Return numberIN


#--------------------Main Program----------------------

#====> Ask the user to input a number
#====> Cast the input to integer as it is assigned to userNumber


#====> Call the moduloByTwo subprogram
#====> Use userNumber as the argument
#====> Assign the returned value to result


#====> Use a conditional statement to test result
#====> If the value is greater than 0 the program will output "Odd"
#====> Otherwise it will output "Even".

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
# 6.2 Practical Activity 6

#-------------Global Variables------------------

#====> Initialise a variable called testScore
#====> Assign the integer 0 to it


#====> Initialise a variable called grade
#====> Assign an empty string to it


#--------------------Subprograms-----------------------

# Creating a subprogram called determineGrade
# It takes one parameter called score

def determineGrade(score):
  #====> The subprogram will use a branched conditional statement
  #====> to assign the correct grade to the global variable grade.
  #====> If score is greater than or equal to 90, return A*
  #====> If score is greater than or equal to 80, return A
  #====> If score is greater than or equal to 70, return B
  #====> If score is greater than or equal to 60, return C
  #====> If score is greater than or equal to 50, return D
  #====> If score is greater than or equal to 40, return E
  #====> Otherwise return U









#--------------------Main Program----------------------

#====> Ask the user to input their test score
#====> Cast the input to integer as it is assigned to testScore


#====> Call the determineGrade subprogram
#====> assign its return value to grade


#====> Output a message stating what the grade is

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
# 6.2 Practical Activity 7

#-------------Global Variables------------------

#====> Initialise a variable called userPassword
#====> Assign an empty string to it


#====> Initialise a variable called resultString
#====> Assign an empty string to it


#--------------------Subprograms-----------------------

#====> Create a subprogram called passwordCheck
#====> It must have one parameter called passwordIn

  # Using the len function to determine how many
  # characters long the password is. It then assigns
  # an integer containing the length of the word to
  # the wordLen variable
  wordLen = len(passwordIn)

  #====> Use a conditional statement to test if the value
  #====> of wordLen is below 8 characters long
  #====> If it is below 8 characters long it will return
  #====> "invalid", otherwise it will return "valid".





#--------------------Main Program----------------------
#====> Ask the user to input their password
#====> Assign their input to userPassword


#====> Call the passwordCheck subprogram
#====> Use userPassword as the argument
#====> Assign the returned value to resultString


#====> Use a conditional statement to test resultString
#====> If the value is "invalid" the program will output the string
#====> "Your password is too short".
#====> Otherwise it will output "Your password is valid".

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
# 6.2 Practical Activity 8

#-------------Global Variables------------------

#====> Initialise a variable called userAge
#====> Assign the integer 0 to it


#--------------------Subprograms-----------------------

#====> Create a subprogram called ageCheck
#====> It must have one parameter called ageIn

  #====> The subprogram will use a branched conditional statement
  #====> to output the correct film rating.
  #====> Use the >= relational operator to determine the correct
  #====> rating of film for their age.
  #====> 18, 15, 12, PG, U





#--------------------Main Program----------------------

#====> Ask the user to input their age
#====> Cast the input to integer as it is assigned to userAge


#====> Call the ageCheck subprogram
#====> Use userAge as the argument

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
# 6.2 Practical Activity 9

#-------------Global Variables------------------

#====> Initialise a variable called userWord
#====> Assign an empty string to it


#--------------------Main Program----------------------

#====> Ask the user to input a word no longer than 3 letters.
#====> Assign their input to userWord


#====> Use a conditional statement and the len() function to test the word
#====> If the word is longer than 3 letters, output "Incorrect"
#====> Otherwise, output "Correct"

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
# 6.2 Practical Activity 10

#-------------Global Variables------------------

#====> Initialise a variable called numOne
#====> Assign the integer 0 to it


#====> Initialise a variable called numTwo
#====> Assign the integer 0 to it


#====> Initialise a variable called multipliedAnswer
#====> Assign the integer 0 to it


#====> Initialise a variable called result
#====> Assign the integer 0 to it


#--------------------Main Program----------------------

#====> Ask the user to input number 1
#====> Cast the input to integer as it is assigned to numOne


#====> Ask the user to input number 2
#====> Cast the input to integer as it is assigned to numTwo


#====> Multiply numOne by numTwo and
#====> Assign it to multipliedAnswer


#====> Use a conditional statement to test if multipliedAnswer is
#====> greater than 100. If it is, then the program
#====> outputs "The answer is over 100".


#====> Calculate the modulo of multipliedAnswer when divided by 2
#====> Assign the answer to result


#====> Use a conditional statement to test result
#====> If the value is greater than 0 the program will output "Odd"
#====> Otherwise it will output "Even".
