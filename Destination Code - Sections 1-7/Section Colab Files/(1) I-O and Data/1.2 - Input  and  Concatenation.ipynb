# %%
#1.2 - Practice 1

#----------------Global Variables----------------------
"""
LONG COMMENT
----------------
Below you can see that two variables have been initialised below
Each of these is assigned an empty value (nothing)

This is important because later in the program, they will have
new values assigned to each of them.
-----------------------------------------------"""

# Initialising a variable called first name
# Assigning an empty value to it
firstName = ""

# Initialising a variable called secondName
# Assigning an empty value to it
secondName = ""

#-------------------Main Program-------------------------
"""
LONG COMMENT
--------------------
In the code below you can see the firstName variable
is being assigned a new value and this will come
from a user input.

You will notice that there are brackets after the word input.

Inside the brackets is a message that, when the program is run,
will tell the user what they must type.
-------------------------------------"""

# Asking the user to enter their first name
# Assigning their input to the variable firstName
firstName = input("Enter your first name: ")

#====> Ask the user to enter their second name
#====> Assign their input to the variable secondName


#====> Fix the line of code below so it outputs Hello
#====> followed by their first name and second name
print("Hello", , )

# %% [markdown]
# .</br>
# .</br>
# .</br>

# %%
#1.2 - Practice 2
#----------------Global Variables----------------------
#====> Initialise a variable called userAnswer
#====> Assign an empty value to it


#------------------Main Program------------------------
#====> Ask the user to input a place they would like to visit
#====> Assign their input to the variable userAnswer


# Outputting a message that includes the value of userAnswer
print(userAnswer,"That sounds lovely!")

# %% [markdown]
# .</br>
# .</br>
# .</br>

# %%
#1.2 - Practice 3

#------------------Global Variables---------------------

# Initialising a variable called breadType
# Assigning and empty value to it
breadType = ""

#====>Initialise a variable called filling
#====>Assign an empty value to it


#-------------------Main Program--------------------------

# Outputting a message about the program
print("Welcome to the wonderful sandwich maker")

# Asking the user to input the type of bread they want
# Assigning the user input to the variable breadType
breadType = input("Enter the type of bread you want: ")

#====> Ask the user to input the filling they want
#====> Assign the user input to the variable filling


#Outputting to confirm the type of bread they want
print("You ordered a sandwich with", breadType, "bread")

#====>Complete the missing code to confirm the filling
print("The sandwich filling is", )

# %% [markdown]
# .</br>
# .</br>
# .</br>

# %%
#1.2 - Practice 4

#------------------Global Variables---------------------
#====>Initialise a variable called destination
#====>Assign an empty value to it


#====>Initialise a variable called transport
#====>Assign an empty value to it


#------------------Main Program--------------------------

# Outputting a message to explain how the program works
print("Welcome to the journey booking system")

#====> Ask the user to input where they wish to go
#====> Assign their input to the variable destination


#====> Ask the user to input how they wish to get there
#====> Assign their input to the variable transport


# Outputting a message to confirm the destination
print("You wish to travel to", destination)

#====> Output a message to confirm the mode of transport

# %% [markdown]
# .</br>
# .</br>
# .</br>

# %%
#1.2 - Practice 5

#------------------Global Variables---------------------

# Initialising a variable called day
# Assigning an empty value to it
day = ""

#====> Initialise a variable called month
#====> Assign an empty value to it


#====> Initialise a variable called year
#====> Assign an empty value to it


# Initialising a variable called DOB
# Assigning an empty value to it
DOB = ""

#------------------Main Program-------------------------

# Outputting a message about the program
print("We will create your date of birth")

# Asking the user to input they day they were born
# Assigning their input to the variable day
day = input("Enter the number of the day you were born: ")

#====> Ask the user to input they number of the month they were born
#====> Assign their input to the variable month
month

#====> Ask the user to input they number of the year they were born
#====> Assign their input to the variable year
year

"""
The line below takes each of the three variables
and concatenates them, along with / symbols.

This concatenated text is then assigned to the DOB
variable.

Concatenation means to join strings of text together
into a single string of text, using the + symbol."""

# Concatenating several values to make a new string
# This is then assigned to DOB
DOB = day + "/" + month + "/" + year

#====> Complete the line below to include only one variable
#====> at the end. Guess which one it will be???
print("Your date of birth is:", )

# %% [markdown]
# .</br>
# .</br>
# .</br>

# %%
#1.2 - Practice 6

#------------------Global Variables---------------------

# Initialising a variable called firstName
# Assigning an empty value to it
firstName = ""

#====> Initialise a variable called secondName
#====> Assign an empty value to it


#-------------------Main Program------------------------

# Outputting a message about the program
print("Welcome to the username generator")

#====> Ask the user to input their first name
#====> Assign their input to the variable firstName


#====> Ask the user to input their second name
#====> Assign their input to the variable secondName


#====> Concatenate the firstName and secondName variables
#====> along with some other characters so it should
#====> make a username with this format dionne.brown27
#====> Assign the string to the variable userName
userName =

#====> Output a message, telling the user their username.

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
#1.2 - Practice 7

#------------------Global Variables---------------------

#====> Initialise a variable called townName
#====> Assign an empty value to it


#====> Initialise a variable called teamType
#====> Assign an empty value to it


#-------------------Main Program------------------------

# Outputting a message about the program
print("Welcome to the football team name generator")

#====> Ask the user to input the name of a town
#====> Assign their input to the variable townName


#====> Ask the user to input either "united", "town" or "athletic"
#====> Assign their input to the variable teamType


#====> Concatenate the townName and teamType variables
#====> along with a space to make the football team name
#====> Assign the string to the variable teamName


#====> Output a message, telling the user the football team name.

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
#1.2 - Practice 8

#------------------Global Variables---------------------

#====>  Initialise a variable called celebrityName
#====>  Assign an empty value to it


#====>  Initialise a variable called cityName
#====>  Assign an empty value to it


#-------------------Main Program------------------------

# Outputting a message about the program
print("Welcome to the airport name generator")

#====>  Ask the user to input the name of a celebrity
#====>  Assign their input to the variable celebrityName


#====>  Ask the user to input the name of a city
#====>  Assign their input to the variable cityName


#====>  Concatenate the celebrityName and cityName variables
#====>  along with a space to make the airport name
#====>  Assign the string to the variable airportName



#====> Output a message, telling the user the airport name.

# %% [markdown]
# .</br>
# .</br>
# .</br>

# %%
#1.2 - Practice 9

#------------------Global Variables---------------------

#====> Initialise a variable called filling1
#====> Assign an empty value to it


#====> Initialise a variable called filling2
#====> Assign an empty value to it


#====> Initialise a variable called filling3
#====> Assign an empty value to it


#====> Initialise a variable called sandwichName
#====> Assign an empty value to it


#-------------------Main Program------------------------

# Outputting a message about the program
print("Welcome to the sandwich name generator")

#====> Ask the user to input the first filling
#====> Assign their input to the variable filling1


#====> Ask the user to input the second filling
#====> Assign their input to the variable filling2


#====> Ask the user to input the third filling
#====> Assign their input to the variable filling3


#====> Concatenate the filling1, filling2 and filling3 variables
#====> along with & and Sandwich to make the sandwich name
#====> Assign the string to the variable sandwichName


#====> Output a message, telling the user the sandwich name.

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
# 1.2 - Practice 10

# ------------------Global Variables---------------------

#====> Initialise a variable called firstName
#====> Assign an empty value to it


#====> Initialise a variable called characteristic
#====> Assign an empty value to it


#====> Initialise a variable called vikingName
#====> Assign an empty value to it


# -------------------Main Program------------------------

# Outputting a message about the program
print("Welcome to the Viking name generator")

#====> Ask the user to input their first name
#====> Assign their input to the variable firstName


#====> Ask the user to input a characteristic such as brave or old
#====> Assign their input to the variable characteristic


#====> Concatenate the firstName and characteristic variables
#====> along with " the " to make the Viking name
#====> Assign the string to the variable vikingName


#====> Output a message, telling the user their Viking name.
