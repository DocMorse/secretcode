# %%
#5.3 Practical Activity 1

"""
LONG COMMENT- Functions
-----------------------

-------------------------------------
"""

#-------------Global Variables------------------


#-------------Subprograms------------------------
"""
LONG COMMENT
-------------------------------------------------

"""


#--------------------Main Program----------------------
