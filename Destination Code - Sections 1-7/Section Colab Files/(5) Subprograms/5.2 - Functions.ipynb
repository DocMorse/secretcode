# %%
#5.2 Practical Activity 1

"""
LONG COMMENT- Functions
-----------------------
So far all of the subprograms you have used are called
procedures.

This means they simply carry out a sequence of instructions and end

We will now exlore functions. These are subprograms that can
return a value to the rest of the program.
-------------------------------------
"""

#-------------Global Variables------------------

# Initialising all of the variables to be used in the program
# and assigning empty strings to each.
firstName = ""
secondName = ""
userName = ""

#-------------Subprograms------------------------
"""
LONG COMMENT
-------------------------------------------------
Below you can see a function is being declared.
We know this is a function because it returns a value.

Later on in line 60 of the code we are able to assign
this return value to a variable.

We do this by assigning the function call itself to
the variable.
"""

def makeLogin(fn, sn):
  # Taking parameters and concatenating them with the number 29
  newUser = fn + sn + "29"

  # Returning the newuser variable to the rest of the program.
  return newUser

#--------------------Main Program----------------------

# Asking the user to input their first name
# This is then added to the firstName variable
firstName = input("Enter your first name: ")

# Asking the user to input their second name
# This is then added to the secondName variable
secondName = input("Enter your second name: ")

# Calling the makeLogin subprogram into action
# Assigning the makeLogin function to the userName
# variable. Essentially this takes the return value from
# the function, as defined above and assigns this to the
# variable.
userName = makeLogin(firstName, secondName)

# Outputting a message, telling the user their new
# login
print("Your new login is", userName)

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
#5.2 Practical Activity 2

#----------------Global Variables-------------------------

#====> Initialise a variable called word
#====> Assign an empty string to it


# Initialising a variable called
# Assinging an empty string to it
stringLength = ""

#-----------------Subprograms------------------------------
# Defining a subprogram called wordLength
# Giving it the paramater w
def wordLength(w1):
  #====> Initialise a variable called length
  #====> use the len() function to output the length of the
  #====> string and assign this to the length variable.

  # Returning the length variable to the rest of the program
  return length

#-----------------Main Program-------------------------------
#====> Ask the user to input a string in order to see its length
#====> Assign the value they input to the word variable


#====> Call the wordLength function and use the word variable
#====> as the argument.
#====> Assign this function call to the stringLength variable


#====> Output a message giving the user the string they typed in
#====> and its length.

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
#5.2 Practical Activity 3

#----------------Global Variables-------------------------

#====> Initialise three variables called item1, item2 and item3
#====> Assign an empty string to each of them
item1
item2
item3 = ""

#====> Initialise a variable called foodString
#====> Assign an empty string to it



#-----------------Subprograms------------------------------
# Defining a subprogram called foodItems
# Giving it the paramaters item1, item2 and item3
def foodItems(item1, item2, item3):
  #====> Initialise a variable called foodCombination
  #====> and assign the three parameters to it in a string,
  #====> separated by spaces.


  #====> Return the foodCombination variable to the rest of the program


#-----------------Main Program-------------------------------
#====> Ask the user to input three food items (complete missing code)
#====> Assign the values they input to the item1, item2 and item3
#====> variables respectively.
item1 = input("Enter your first food item: ")
item2
item3

#====> Call the foodItems function and use the item1, item2
#====> and item3 variables as the arguments.
#====> Assign this function call to the foodString variable


#====> Output a message giving the user the string that was returned
#====> by the foodItems function.
print("You ordered", )

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
#5.2 Practical Activity 4

#----------------Global Variables-------------------------

#====> Initialise two variables called side1 and side2
#====> Assign an empty integer to each of them



#====> Initialise a variable called area
#====> Assign 0 to it


#-----------------Subprograms------------------------------
# Defining a subprogram called rectangleArea
# Giving it the paramaters s1 and s2
def rectangleArea(s1, s2):
  #====> Initialise a variable called rectArea
  #====> Calculate the area of the rectangle and assign this
  #====> to the rectArea variable.


  #====> Return the rectArea variable to the rest of the program


#-----------------Main Program-------------------------------
#====> Ask the user to input a number for side 1 of the rectangle
#====> Assign this input to the variable side1
#====> Cast side1 to an integer


#====> Ask the user to input a number for side 2 of the rectangle
#====> Assign this input to the variable side2
#====> Cast side1 to an integer


#====> Call the rectangleArea function and use the side1 and side2
#====> variables as the arguments.
#====> Assign this function call to the area variable


# Outputting a message giving the user the area of the rectangle.
print("The area of the rectangle is", area)

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
# 5.2 Practical Activity 5

# ---------------Global Variables-------------------------

# ====> Initialise a variable called radius
# ====> Assign an empty integer to it


# ====> Initialise a variable called area
# ====> Assign 0 to it


# ====> Initialise a Constant called PI
# ====> Assign the value 3.14 to it


# -----------------Subprograms------------------------------
# Defining a subprogram called circleArea
# It takes the parameter r to handle the radius
# It takes the parameter p to handle pi to a set
# number of decimal places

def circleArea(r, p):
  # ====> Initialise a variable called circleArea
  # ====> Calculate the area of the circle and assign this
  # ====> to the circleArea variable.
  # ====> The formula for this will be PI X radius ** 2

  # ====> Return the circleArea variable to the rest of the program
  return circleArea

# -----------------Main Program-------------------------------
# ====> Ask the user to input a number for the radius of the circle
# ====> Assign this input to the variable radius
# ====> Cast radius to an integer


# ====> Call the circleArea function
# ====> Use the radius variable and PI variables as arguments.
# ====> Assign this function call to the area variable


# Outputting a message giving the user the area of the circle.
print("The area of the circle is", area)

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
# 5.2 Practical Activity 6

# ---------------Global Variables-------------------------

# ====> Initialise a variable called radius
# ====> Assign an empty integer to it
=

# ====> Initialise a variable called height
# ====> Assign an empty integer to it


# ====> Initialise a variable called volume
# ====> Assign 0 to it


# ====> Initialise a Constant called PI
# ====> Assign the value 3.14 to it


# -----------------Subprograms------------------------------
# Defining a subprogram called cylinderVolume
# It takes the parameter r to handle the radius
# It takes the parameter h to handle the height
# It takes the parameter p to handle pi to a set
# number of decimal places

def cylinderVolume(r, h, p):
    # ====> Initialise a variable called cylinderVolume
    # ====> Calculate the volume of the cylinder and assign this
    # ====> to the cylinderVolume variable.
    # ====> The formula for this will be PI * radius ** 2 * height


    # ====> Return the cylinderVolume variable to the rest of the program


# -----------------Main Program-------------------------------
# ====> Ask the user to input a number for the radius of the cylinder
# ====> Assign this input to the variable radius
# ====> Cast radius to an integer



# ====> Ask the user to input a number for the height of the cylinder
# ====> Assign this input to the variable height
# ====> Cast height to an integer



# ====> Call the cylinderVolume function
# ====> Use the radius, height, and PI variables as arguments.
# ====> Assign this function call to the volume variable


# Outputting a message giving the user the volume of the cylinder.
print("The volume of the cylinder is", volume)

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
# 5.2 Practical Activity 8

# ---------------Global Variables-------------------------

# ====> Initialise two variables called country and capital
# ====> Assign an empty string to each of them
country = ""
capital = ""

# ====> Initialise a variable called countryCapitalString
# ====> Assign an empty string to it
countryCapitalString = ""


# -----------------Subprograms------------------------------
# ====> Define a subprogram called createCountryCapitalString
# ====> It must take the parameter co to handle the country
# ====> It must take the parameter ca to handle the capital

def createCountryCapitalString(co, ca):
    # Initialising a variable called outputString
    # Concatenating the country and capital, with the phrase
    # " is the capital of " in between co and ca
    # Assigning this to the outputString variable
    outputString = co + " is the capital of " + ca

    # ====> Return the outputString variable to the rest of the program



# -----------------Main Program-------------------------------
# ====> Ask the user to input a country
# ====> Assign this input to the variable country


# ====> Ask the user to input the capital of that country
# ====> Assign this input to the variable capital


# ====> Call the createCountryCapitalString function
# ====> Use the country and capital variables as arguments.
# ====> Assign this function call to the countryCapitalString variable


# Outputting a message giving the user the generated string.
print(countryCapitalString)

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
#5.2 Practical Activity 9
# ---------------Global Variables-------------------------

# ====> Initialise two variables called dinosaur and diet
# ====> Assign an empty string to each of them
dinosaur = ""
diet = ""

# ====> Initialise a variable called dinosaurDietString
# ====> Assign an empty string to it
dinosaurDietString = ""


# -----------------Subprograms------------------------------
# ====> Definine a subprogram called createDinosaurDietString
# ====> It must take the parameter dino to handle the dinosaur
# ====> It must take the parameter food to handle the diet
def :
    # ====> Initialise a variable called outputString
    # ====> Concatenate the dinosaur and diet, with the phrase
    # ====> " has a diet of " in between
    # ====> Assign this to the outputString variable


    # ====> Return the outputString variable to the rest of the program



# -----------------Main Program-------------------------------
# ====> Ask the user to input a type of dinosaur
# ====> Assign this input to the variable dinosaur


# ====> Ask the user to input the diet of that dinosaur
# ====> Assign this input to the variable diet


# ====> Call the createDinosaurDietString function
# ====> Use the dinosaur and diet variables as arguments.
# ====> Assign this function call to the dinosaurDietString variable


# Outputting a message giving the user the generated string.
print(dinosaurDietString)

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
#5.2 Practical Activity 10

#----------------Library Imports--------------------------
# Importing the math library to use with math.sqrt later on
import math

# ---------------Global Variables-------------------------

# ====> Initialise a variable called number
# ====> Assign an empty integer to it
number = 0

# ====> Initialise a variable called squareRoot
# ====> Assign 0 to it
squareRoot = 0

# -----------------Subprograms------------------------------
# Definine a subprogram called calculateSquareRoot
# It must take the parameter num to handle the number entered
def :
    # ====> Initialise a variable called root
    # ====> Calculate the square root of the number and assign this
    # ====> to the root variable. Use math.sqrt(<number goes here>)


    # ====> Return the root variable to the rest of the program


# -----------------Main Program-------------------------------
# ====> Ask the user to input a number
# ====> Assign this input to the variable number
# ====> Cast number to an integer



# ====> Call the calculateSquareRoot function
# ====> Use the number variable as an argument.
# ====> Assign this function call to the squareRoot variable


# Outputting a message giving the user the square root of the number.
# ====> Fix this output so it contains the correct variable names
print("The square root of", ???, "is", ???)
