# %%
#8.1 Example

"""
LONG COMMENT
----------------
Iteration involves looping
--------------------------------
"""

#---------------Global Variables-------------------

# There are no global variables in this program

#---------------Main Program-----------------------

for count in range(1,11,1):
  print(count)

# %% [markdown]
# .<br>
# .<br>
# .<br>
