# %%
#2.1 Practical Activity 1

"""
LONG COMMENT
-----------------------
The code below will complete the function of a basic calculator.
This will take the values of of two variables and add them together.

The data type of each variable is integer(whole number).
In the previous activities you have only worked with string data
(text in speech marks).

Run the program and see what happens
"""

#-------------Global Variables------------------

# Initialising a variable called numberOne and assigning the integer
# 12 to it.
numberOne = 12

# Initialising a variable called numberTwo and assigning the integer
# 8 to it.
numberTwo = 8

# Initialising a variable called answer and assigning the integer
# 0 to it.
answer = 0

#--------------------Main Program----------------------

# Adding the values of numberOne and numberTwo
# Then assigning this to a the variable answer

answer = numberOne + numberTwo

# Outputting the calculation and the answer
print(numberOne, "+", numberTwo, "=", answer)

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
#2.1 Practical Activity 2

#-------------Global Variables------------------

# Initialising a variable called numberOne and assigning the integer
# 15 to it.
numberOne = 15

# Initialising a variable called numberTwo and assigning the integer
# 5 to it.
numberTwo = 5

# Initialising a variable called answer and assigning the integer
# 0 to it.
answer = 0

#--------------------Main Program----------------------

# Multiplication

#====> Using the operator *
#===> multiply numberOne and numberTwo
#===> Assign the result to the answer variable
answer =

#====> Output a meaningful message that tells the user
#====> what numberOne multiplied by numberTwo is
print()

# Division

#====> Using the operator /
#===> divide numberOne by numberTwo
#===> Assign the result to the answer variable
answer =

#====> Output a meaningful message that tells the user
#====> what numberOne divided by numberTwo is
print()

# Subtraction

#====> Using the operator -
#===> subtract numberTwo from numberOne
#===> Assign the result to the answer variable
answer =

#====> Output a meaningful message that tells the user
#====> what numberTwo subtracted from numberOne is
print()

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
#2.1 Practical Activity 3

"""
LONG COMMENT
----------------
Exponentiation is when we multiply a number to the power of
another number. For example 2 to the power of 2 (or 2 squared)
is the same as 2 X 2.

2 to the power of 3 (or 2 cubed) is the same as 2 X 2 X 2.

To represent exponentiation (powers) we use a double asterisk (**)

2 to the power of 2 is represented as 2 ** 2.
2 to the power of 3 is represented as 2 ** 3.

--------------------
"""

#--------------Global Variables----------------
#====> Initialise a variable called firstNumber
#====> Assign a zero value (0) to the variable


#====> Initialise a variable called answer
#====> Assign a zero value (0) to the variable


#---------------Main Program-------------------
#====> Assign the value 5 to the variable firstNumber


#====> Calculate the firstNumber variable to the power of 3
#====> Assign the result to the answer variable


#====> Output a message stating the value of firstNumber
#====> to the power of 3, along with the answer variable.

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
#2.1 Practical Activity 4

#--------------Global Variables----------------
#====> Initialise a variable called theNumber
#====> Assign a zero value (0) to the variable


#--------------Main Program--------------------
#====> Assign the value 4 to the variable theNumber


#====> Calculate the theNumber variable to the power of 4
#====> Assign the result to the answer variable


#====> Output a message stating the value of theNumber
#====> to the power of 4, along with the answer variable.

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
# 2.1 Practical Activity 5

#--------------Global Variables----------------
#====> Initialise a variable called numberOne
#====> Assign the value 6 to the variable


#====> Initialise a variable called numberTwo
#====> Assign the value 3 to the variable


# Initialising a variable called answer and
# assigning a zero value to the variable
answer = 0

#----------------Main Program------------------
#====> Calculate numberOne to the power of numberTwo
#====> Assign the result to the answer variable


#====> Output a message stating what numberOne to the
#====> power of numberTwo is.

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
#2.1 Practical Activity 6

"""
LONG COMMENT
----------------
In this activity you will learn to carry out integer division
This divides one number by another, however if the answer
includes a decimal value it is rounded down to the nearest
whole number.

The operator used for integer division is //
------------------------------------------------------
"""

#------------------Global Variables---------------------
#====> Initialise a variable called valueOne
#====> Assign a zero value to it


#====> Initialise a variable called valueTwo
#====> Assign a zero value to it


# Initialising the answer variable and assigning
# the value 0 to it
answer = 0

#-----------------Main Program---------------------------
#====> Assign the value 13 to valueOne


#====> Assign the value 2 to valueTwo


#====> Use integer division (//) to divide valueOne by valueTwo
#====> Assign the result to the answer variable


#====> Output a message stating the result of an integer division
#====> on valueOne and valueTwo is answer.

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
#2.1 Practical Activity 7

"""
LONG COMMENT
----------------
In this activity you will learn to carry out the modulus
operation. This returns remainder from a division calculation.

The operator used for modulus is %

For example, 7 % 2 = 1
This is because the nearest whole number to 7, that can be
divided by 2 is 6. The difference between 7 and 6 is 1, hence
the remainder being 1.

Also 7 % 3 = 1
Again this is because the nearest whole number to 7, that can be
divided by 3 is also 6. The difference between 7 and 6 is 1, hence
the remainder being 1.
------------------------------------------------------
"""

#------------------Global Variables---------------------

#====> Initialise a variable called numOne
#====> Assign the value 15 to it.


#====> Initialise a variable called numTwo
#====> Assign the value 4 to it.


#====> Initialise a variable called answer
#====> Assign the value 0 to it


#------------------Main Program--------------------------

#====> Calculate the result of numOne modulus (%) numTwo
#====> Assign the result to the answer variable.


#====> Output a message stating the result of the modulus operation
#====> between numOne and numTwo.

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
#2.1 Practical Activity 8

#----------------Global Variables--------------
firstNum = 23

secondNum = 6

#----------------Main Program------------------
"""
LONG COMMENT
---------------
For each of the following outputs, they should include
a suitable message to explain the output.
---------------
"""

#====> Output the result of firstNum added to secondNum


#====> Output the result of firstNum minus secondNum


#====> Output the result of firstNum multiplied by secondNum


#====> Output the result of firstNum divided by secondNum


#====> Output the result of firstNum modulus secondNum


#====> Output the result of integer division on firstNum with secondNum


#====> Output firstNum to the power of 3

# %% [markdown]
# .<br>
# .<br>
# .<br>
