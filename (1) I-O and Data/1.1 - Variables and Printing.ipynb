# %%
#1.1 - Practice Activity 1

"""
LONG COMMENT
------------------------
In the code below I have initialised(created)
two variables(named pieces of memory). They are called
pastryType and pieType.

Each of these has been assigned (given) a value.

In the case of the variable called pieType the value it has
been assigned is "Apple".

When you assign a value to a variable you must type
the name of the variable, followed by an = sign, followed
by the value you wish to assign to it
--------------------------------------------------------------------"""

#--------Global Variables------------

# Initialising a variable called pastryType
# Assigning the value "puff pastry" to it
pastryType = "puff pastry"

# Initialising a variable called pieType
# Assigning the value "apple" to it
pieType = "apple"

"""
LONG COMMENT
----------------------------
The section of code below is the main program. This
section is used for all of the active code. Code that
does something.

In the code I am using the print function to output a message
to the screen.

You can clearly see the output contains a message and the name
of each variable.

Have a think about what this program might do, press the play
button and see if you guessed correctly.
----------------------------------------------------------------"""

#--------Main Program----------------

# Outputting a message that contains both of my variables
print("I want to eat", pastryType, pieType, "pie")

# %% [markdown]
# .</br>
# .</br>
# .</br>

# %%
#1.1 - Practice Activity 2

"""
LONG COMMENT
----------------------------
You will now get to edit some code.

All lines that begin with # are comments. Python will ignore
them and move to the next line of code.
Anything not in three speech marks or on a line beginning with #
is active code.

Any comment lines that have the format #====> are instructions
for what you must do to the code below them.
-------------------------------------------"""

#--------Global Variables------------
#====> Assign the value "puff pastry"
#====> to the variable pastryType
pastryType

#====> Assign the value "blueberry"
#====> to the variable pieType
pieType

#--------Main Program----------------
print("I want to eat", pastryType, pieType,"pie")

# %% [markdown]
# .</br>
# .</br>
# .</br>

# %%
#1.1 - Practice Activity 3

#-------Global Variables-----------
petType = "dog"

#====> Initialise a new variable and call it place
#====> Assign the value "park" to it



#-------Main Program----------------

# Outputting a message that contains both variables
print("Today I took my pet", petType, "to the", place)


# Assigning a new value to the variable petType
petType = "parrot"


#====> Assign a new value to the variable place


#====> Use the print function to output a new message
#====> It should output the new place you took your new pet

# %% [markdown]
# .</br>
# .</br>
# .</br>

# %%
#1.1 - Practice Activity 4

#-------Global Variables-----------

# Inititalising the variable sauce
# Assigning the value "tomato" to it
sauce = "tomato"

# Inititalising the variable topping
# Assigning the value "hawaiian" to it
topping = "hawaiian"

#-------Main Program---------------
print("My pizza will be", topping, "with", sauce, "sauce")

#====> Assign a new value to the variable sauce


#====> Assign a new value to the variable topping


#====> Output a message that contains the updated variables

# %% [markdown]
# .</br>
# .</br>
# .</br>

# %%
#1.1 - Practice Activity 5

#-------Global Variables---------
#====> Initialise a variable
#====> Its value should be a type of animal


#====> Initialise another variable
#====> Its value should be a type of vehicle


#-------Main Program-------------
print("I must be imagining things")

#====> Fill in the gaps with your variable names
print("Today I saw a", ,"driving a", )

# %% [markdown]
# .</br>
# .</br>
# .</br>

# %%
#1.1 - Practice Activity 6

#--------Global Variables---------

# Inititalising the variable weatherOne
# Assigning the value "sunny" to it
weatherOne = "sunny"

# Inititalising the variable weatherTwo
# Assigning the value "raining" to it
weatherTwo = "raining"

# Inititalising the variable weatherThree
# Assigning the value "breezy" to it
weatherThree = "breezy"

#--------Main Program-------------

#====> You choose a variable in order to
#====> output a message stating what the weather was yesterday


#====> You choose a variable in order to
#====> output a message stating what the weather is today


#====> You choose a variable in order to
#====> output a message stating what the weather will be tomorrow

# %% [markdown]
# .</br>
# .</br>
# .</br>

# %%
#1.1 - Practice Activity 7

#----------Global Variables----------

#====> Initialise a variable called sense
#====> assign one of the 5 senses to it


#------------Main Program----------------

#====> Output a message stating how you know there is
#====> a pie in the room because you <sense> it.


#====> Assign a new value to the variable sense


#====> Output the message again but this time for
#====> an exercise book instead of a pie

# %% [markdown]
# .</br>
# .</br>
# .</br>

# %%
#1.1 - Practice Activity 8

#----------Global Variables-----------

#====> Fix the code below
place
month


#----------Main Program----------

#====> Output a message about where you have been and when this was

# %% [markdown]
# .</br>
# .</br>
# .</br>
# Assessments
# .</br>
# .</br>
# .</br>

# %%
#1.1 - Assessment Challenge 1

"""Create a program that outputs the best and worst films
you have ever seen"""

# %% [markdown]
# .</br>
# .</br>
# .</br>

# %%
#1.1 - Assessment Challenge 2

"""There are at least three errors in the program below
Fixe them so it runs correctly"""

#-------------Global Variables-----------------

starter = bread roll
main = "chicken nuggets and chips
dessert = "ice cream"

#-------------Main Program---------------------
print(I will order, starter,",", main, "and", dessert)
