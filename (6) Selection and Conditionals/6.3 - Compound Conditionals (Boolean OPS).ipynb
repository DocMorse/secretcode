# %%
#6.3 Practical Activity 1

"""
LONG COMMENT- Compound Conditional Statements
-----------------------
In the next few activities you will work with
compound conditional statements.

This is where we can test two conditions at once.

How we do this is to join both conditions
with boolean operators: and, or, not.

end of comment
-------------------------------------
"""

#-------------Global Variables------------------

# Initialising a variable called day
# Assigning the string "friday" to it.
day = "friday"

# Initialising a variable called number
# Assigning the string 13th to it.
number = "13th"

#--------------------Subprograms-----------------------

# No subprograms are used in this example

#--------------------Main Program----------------------

# Using a compoud conditional statement
# to check if day is friday and
# number is 13th.
if day == "friday" and number == "13th":
  print("Unlucky")
else:
  print("Lucky")

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
#6.3 Practical Activity 2

#-------------Global Variables------------------

#====> Initialise a variable called  colourOne
#====> Assign an empty string value to it.


#====> Initialise a variable called colourTwo
#====> Assign an empty string to it


#--------------------Subprograms-----------------------

# No subprograms are used in this activity

#--------------------Main Program----------------------

#====> Ask the user to input a colour
#====> use the .lower() function on the input
#====> Assign the user input to colourOne


#====> Ask the user to input another colour
#====> use the .lower() function on the input
#====> Assign the user input to colourTwo


#====> Use the or boolean operator, within
#====> a compound conditional statement,
#====> to determine if the value of either
#====> variable is "blue"

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
#6.3 Practical Activity 3

"""
LONG COMMENT - Procedures and functions
------------------------------------------
In this activity I use the word procedure.

This is what we call a subprogram that doesn't
return a value to the main program
(like a function does).

Instead it justs performs a task and then ends.

You have used procedures quite a lot but up until
this point I have only referred to them as subprograms.

end of comment
-------------------------------------
"""

#-------------Global Variables------------------

#====> Initialise a variable called  userName
#====> Assign an empty string value to it.


#====> Initialise a variable called password
#====> Assign an empty string to it


#--------------------Subprograms-----------------------

# Defining a procedure called pwCheck
# It has the parameters uN and pW
def pwCheck(uN, pW):

  #====> Use a compound conditional statement
  #====> to check if uN is equal to "bob" and
  #====> pW is equal to "password123"
  #====> It will output "access granted" if both
  #====> are a match and "access denied" if they
  #====> don't match


#--------------------Main Program----------------------

#====> Ask the user to input a username
#====> use the .lower() function on the input
#====> Assign the user input to userName


#====> Ask the user to input a password
#====> DO NOT!!!! use the .lower() function on the input
#====> Assign the user input to password


#====> Call the pwCheck procedure
#====> use userName and password as arguments

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
# 6.3 Practical Activity 4

#-------------Global Variables------------------

#====> Initialise a variable called name1
#====> Assign an empty string value to it.


#====> Initialise a variable called name2
#====> Assign an empty string to it


#====> Initialise a variable called name3
#====> Assign an empty string to it


#====> Initialise a variable called result
#====> Assign an empty string to it


#--------------------Subprograms-----------------------

#====> Definine a function called nameCheck
#====> It will take the parameters n1, n2 and n3
def nameCheck(n1, n2, n3):
    #====> Use a compound conditional statement
    #====> to check if n1, n2 or n3  is equal to "bob"
    #====> It will return "match" if one of them is "bob"
    #====> and return "no match" if they are not a match





#--------------------Main Program----------------------

#====> Ask the user to input the first name
#====> use the .lower() function on the input
#====> Assign the user input to name1


#====> Ask the user to input the second name
#====> use the .lower() function on the input
#====> Assign the user input to name2


#====> Ask the user to input the third name
#====> use the .lower() function on the input
#====> Assign the user input to name3


#====> Call the nameCheck function
#====> use name1, name2 and name3 as arguments
#====> Assign the return value to the
#====> result variable


#====> Use a conditional statement to check
#====> if the returned value from the function is "match"
#====> If it is, output "bob found"
#====> otherwise output "bob not found"

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
# 6.3 Practical Activity 5

#-------------Global Variables------------------

#====> Initialise a variable called kingdom
#====> Assign an empty string value to it.



#--------------------Subprograms-----------------------

#====> Definine a procedure called checkKingdom
#====> It will take the parameter k

  #====> Use a compound conditional statement
  #====> to check if k is equal to "fish", "reptiles", "birds",
  #====> "mammals" or "insects"
  #====> Output the name of the kingdom if it is a match
  #====> Output "Unknown kingdom" if they are not a match





#--------------------Main Program----------------------

#====> Ask the user to input the name of an animal kingdom
#====> use the .lower() function on the input
#====> Assign the user input to kingdom


#====> Call the checkKingdom procedure
#====> use kingdom as an argument

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
# 6.3 Practical Activity 6

#-------------Global Variables------------------

#====> Initialise a variable called num1
#====> Assign the integer 0 to it


#====> Initialise a variable called result
#====> Assign an empty string to it


#--------------------Subprograms-----------------------

#====> Define a function called validRange
#====> It should take one parameter n


  # The parameter n is tested to see
  # if it falls within a particular
  # range of numbers (10-20).
  # If it does the function returns "Valid"
  # If it doesn't it returns "Invalid"
  if n >= 10 and n <= 20:
    return "Valid"
  else:
    return "Invalid"

#-------------Main Program-----------------

#====> Ask the user to input a number between
#====> 10 and 20. Cast the input to integer
#====> as it is assigned to the variable num1


#====> Call the function validRange into action
#====> Assign its return value to the variable result.


# Outputting a message about the status of the number
print("If your number was between 10 and 20: ", result)

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
# 6.3 Practical Activity 7

#-------------Global Variables------------------

#====> Initialise a variable called num1
#====> Assign the integer 0 to it


#====> Initialise a variable called num2
#====> Assign the integer 0 to it



#--------------------Subprograms-----------------------

#====> Define a procedure called numCheck
#====> It should take two parameters n1 and n2

  #====> Use a compound conditional statement
  #====> to check if n1 is smaller than 10 and
  #====> n2 is greater than 20
  #====> Output "n1 is less than 10 and n2 is greater than 20"
  #====> if both are a match and "Condition not met" if they
  #====> don't match





#-------------Main Program-----------------

#====> Ask the user to input the first number.
#====> Cast the input to integer
#====> as it is assigned to the variable num1


#====> Ask the user to input the second number.
#====> Cast the input to integer
#====> as it is assigned to the variable num2


#====> Call the procedure numCheck
#====> use num1 and num2 as arguments

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
# 6.3 Practical Activity 8

#-------------Global Variables------------------

#====> Initialise a variable called userAge
#====> Assign the integer 0 to it


#====> Initialise a variable called result
#====> Assign an empty string to it


#--------------------Subprograms-----------------------

#====> Define a function called ageCheck
#====> It should take one parameter userAge

    #====> Use a compound conditional statement
    #====> to check if userAge is between 11 and 16
    #====> It will return "valid" if the condition is met
    #====> and return "invalid" if they are not a match





#-------------Main Program-----------------
#====> Ask the user to enter their age.
#====> Cast the input to integer as it is
#====> assigned to the variable userAge


#====> Call the function ageCheck
#====> use userAge as an argument
#====> Assign the return value to the result variable


#====> Use a conditional statement to check
#====> if the returned value from the function is "valid"
#====> If it is, output "You can attend secondary school"
#====> otherwise output "You cannot attend secondary school"

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
# 6.3 Practical Activity 9

#-------------Global Variables------------------

#====> Initialise a variable called userPW
#====> Assign an empty string value to it.


#--------------------Subprograms-----------------------

# Defining a procedure called pwLengthCheck
# It only takes one parameter (userPW)
def pwLengthCheck(userPW):

  # Initialising a local variable (only exists in this subprogram)
  # Assigning the length of userPW to it (using the len() function)
  pwLength = len(userPW)

  #====> Use a compound conditional statement
  #====> to check if pwLength is between 8 and 25
  #====> It will print "Valid Password Length" if the condition is met
  #====> and print "Invalid Password Length" if they are not a match




#-------------Main Program-----------------
#====> Ask the user to enter their password.
#====> Assign the input to the variable userPW


#====> Call the procedure pwLengthCheck
#====> use userPW as an argument

# %% [markdown]
# .<br>
# .<br>
# .<br>

# %%
# 6.3 Practical Activity 10

#-------------Global Variables------------------

#====> Initialise a variable called userPW
#====> Assign an empty string value to it.


#--------------------Subprograms-----------------------

# No subprograms are used in this activity

#--------------------Main Program----------------------

#====> Ask the user to enter a new password.
#====> It must be 10 characters or greater.
#====> Assign the input to the variable userPW


#====> Use a compound conditional statement to check
#====> if the password entered is greater than 10
#====> characters and is not lowercase
#====> Clue - use the not command to test if it is not
#====> lowercase e.g.
if <enter missing code> and not <string>.islower():
